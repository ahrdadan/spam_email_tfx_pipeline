# %%
#!pip install -U tfx

# %% [markdown]
# # Inisiasi Variabel Directory

# %%
import os

def create_dir(path):
    if not os.path.exists(path):
        os.makedirs(path)

DATA_ROOT   = 'data'
MODULE_PATH = 'module'

create_dir(DATA_ROOT)
create_dir(MODULE_PATH)

# %% [markdown]
# # Create Module
# ---

# %% [markdown]
# ## Create Module Components

# %%
module_components = os.path.join(DATA_ROOT, 'components.py')
# Out:
# 'data\\components.py'

# %%
# %%writefile {module_components}
# """
# Author: Ahmad Ramadhan
# Date: 2024-05-02
# This is the components.py module.
# Usage:
# - COMPONENTS TFX PIPELINE
# """
# import os
# import tensorflow as tf
# import tensorflow_model_analysis as tfma
#
# from tfx.components import (
#     CsvExampleGen,
#     StatisticsGen,
#     SchemaGen,
#     ExampleValidator,
#     Transform,
#     Trainer,
#     Tuner,
#     Evaluator,
#     Pusher)
# from tfx.proto import example_gen_pb2, trainer_pb2, pusher_pb2
# from tfx.dsl.components.common.resolver import Resolver
# from tfx.dsl.input_resolution.strategies.latest_blessed_model_strategy import LatestBlessedModelStrategy
# from tfx.types import Channel
# from tfx.types.standard_artifacts import Model, ModelBlessing
#
# def init_components(
#     data_dir,
#     transform_module,
#     training_module,
#     training_steps,
#     eval_steps,
#     serving_model_dir,
#     tuner_module,
#     tuner_steps
# ):
#     """
#     Initializes components for a machine learning pipeline, optionally with hyperparameter tuning.
#
#     Args:
#         data_dir: Path to the directory containing training and evaluation data.
#         transform_module: Module containing data transformation functions.
#         training_module: Module containing training functions.
#         training_steps: Number of training steps.
#         eval_steps: Number of evaluation steps.
#         serving_model_dir: Directory to save the serving model.
#         tuner_module: Module containing tuner functions.
#     """
#
#     # Examplegen
#     output = example_gen_pb2.Output(
#         split_config = example_gen_pb2.SplitConfig(splits=[
#             example_gen_pb2.SplitConfig.Split(name='train', hash_buckets=3),
#             example_gen_pb2.SplitConfig.Split(name='eval',  hash_buckets=1)
#         ])
#     )
#
#     example_gen = CsvExampleGen(input_base=DATA_ROOT, output_config=output)
#
#     # Statisticgen
#     statistics_gen = StatisticsGen(
#         examples = example_gen.outputs['examples']
#     )
#
#     # Schemagen
#     schema_gen = SchemaGen(
#         statistics = statistics_gen.outputs['statistics']
#     )
#
#     # Validator
#     example_validator = ExampleValidator(
#         statistics = statistics_gen.outputs['statistics'],
#         schema     = schema_gen.outputs['schema']
#     )
#
#     # Transform
#     transform = Transform(
#         examples    = example_gen.outputs['examples'],
#         schema      = schema_gen.outputs['schema'],
#         module_file = os.path.abspath(TRANSFORM_MODULE_FILE)
#     )
#
#     # Tuner
#     tuner = Tuner(
#         module_file     = os.path.abspath(TUNER_MODULE_FILE),
#         examples        = transform.outputs['transformed_examples'],
#         transform_graph = transform.outputs['transform_graph'],
#         schema          = schema_gen.outputs['schema'],
#         train_args      = trainer_pb2.TrainArgs(splits=['train']),
#         eval_args       = trainer_pb2.EvalArgs(splits=['eval'])
#     )
#
#     # Trainer
#     trainer = Trainer(
#         module_file     = os.path.abspath(TRAINER_MODULE_FILE),
#         examples        = transform.outputs['transformed_examples'],
#         transform_graph = transform.outputs['transform_graph'],
#         schema          = schema_gen.outputs['schema'],
#         hyperparameters = tuner.outputs['best_hyperparameters'],
#         train_args      = trainer_pb2.TrainArgs(splits=['train']),
#         eval_args       = trainer_pb2.EvalArgs(splits=['eval'])
#     )
#
#     # Resolver
#     model_resolver = Resolver(
#         strategy_class = LatestBlessedModelStrategy,
#         model          = Channel(type=Model),
#         model_blessing = Channel(type=ModelBlessing)
#     ).with_id('Latest_blessed_model_resolver')
#
#     # Evaluator
#     eval_config = tfma.EvalConfig(
#         model_specs   = [tfma.ModelSpec(label_key = 'Category')],
#         slicing_specs = [tfma.SlicingSpec()],
#         metrics_specs = [
#             tfma.MetricsSpec(metrics=[
#                 tfma.MetricConfig(class_name = 'ExampleCount'),
#                 tfma.MetricConfig(class_name = 'AUC'),
#                 tfma.MetricConfig(class_name = 'FalsePositives'),
#                 tfma.MetricConfig(class_name = 'TruePositives'),
#                 tfma.MetricConfig(class_name = 'FalseNegatives'),
#                 tfma.MetricConfig(class_name = 'TrueNegatives'),
#                 tfma.MetricConfig(class_name = 'BinaryAccuracy',
#                     threshold=tfma.MetricThreshold(
#                         value_threshold = tfma.GenericValueThreshold(
#                             lower_bound = {'value': 0.5}
#                         ),
#                         change_threshold = tfma.GenericChangeThreshold(
#                             direction = tfma.MetricDirection.HIGHER_IS_BETTER,
#                             absolute  = {'value': 0.0001}
#                         )
#                     )
#                 )
#             ])
#         ]
#     )
#
#     evaluator = Evaluator(
#         examples       = example_gen.outputs['examples'],
#         model          = trainer.outputs['model'],
#         baseline_model = model_resolver.outputs['model'],
#         eval_config    = eval_config
#     )
#
#     # Pusher
#     pusher = Pusher(
#         model=trainer.outputs['model'],
#         model_blessing=evaluator.outputs['blessing'],
#         push_destination=pusher_pb2.PushDestination(
#             filesystem=pusher_pb2.PushDestination.Filesystem(
#                 base_directory='serving_model_dir/spam-email-model'
#             )
#         )
#     )
#
#     components = (
#         example_gen,
#         statistics_gen,
#         schema_gen,
#         example_validator,
#         transform,
#         tuner,
#         trainer,
#         model_resolver,
#         evaluator,
#         pusher
#     )
#
#     return components
# Out:
# Writing data\components.py

# %% [markdown]
# ## Create Module Transform

# %%
module_transform = os.path.join(DATA_ROOT, 'transform.py')

# %%
# %%writefile {TRANSFORM_MODULE_FILE}
# """
# Author: Ahmad Ramadhan
# Date: 2024-05-02
# This is the transform.py module.
# Usage:
# - Change text to int for tensorflow
# """
#
# import tensorflow as tf
#
# LABEL_KEY   = "Category"
# FEATURE_KEY = "Message"
#
# # Renaming transformed features
# def transformed_name(key):
#     return key + "_xf"
#
# # Preprocess input features into transformed features
# def preprocessing_fn(inputs):
#     """
#     inputs:  map from feature keys to raw features
#     outputs: map from feature keys to transformed features
#     """
#
#     outputs = {}
#     outputs[transformed_name(FEATURE_KEY)] = tf.strings.lower(inputs[FEATURE_KEY])
#     outputs[transformed_name(LABEL_KEY)]   = tf.cast(inputs[LABEL_KEY], tf.int64)
#
#     return outputs

# %% [markdown]
# ## Create Module Tuner

# %%
module_tuner = os.path.join(DATA_ROOT, 'tuner.py')

# %%
# %%writefile {module_tuner}
# """
# Author: Ahmad Ramadhan
# Date: 2024-05-02
# This is the tuner.py module.
# Usage:
# - For tuning best parameter ML
# """
# import os
# import tensorflow as tf
# import tensorflow_transform as tft
# import keras_tuner as kt
# from tensorflow.keras import layers
# from tfx.components.trainer.fn_args_utils import FnArgs
# from keras_tuner.engine import base_tuner
# from typing import NamedTuple, Dict, Text, Any
#
# LABEL_KEY   = "Category"
# FEATURE_KEY = "Message"
#
# def transformed_name(key):
#     """Renaming transformed features"""
#     return key + "_xf"
#
# def gzip_reader_fn(filenames):
#     """Loads compressed data"""
#     return tf.data.TFRecordDataset(filenames, compression_type='GZIP')
#
# def input_fn(file_pattern, tf_transform_output, num_epochs, batch_size=64) -> tf.data.Dataset:
#     """Get post_tranform feature & create batches of data"""
#
#     # Get post_transform feature spec
#     transform_feature_spec = (
#         tf_transform_output.transformed_feature_spec().copy()
#     )
#
#     # create batches of data
#     dataset = tf.data.experimental.make_batched_features_dataset(
#         file_pattern = file_pattern,
#         batch_size   = batch_size,
#         features     = transform_feature_spec,
#         reader       = gzip_reader_fn,
#         num_epochs   = num_epochs,
#         label_key    = transformed_name(LABEL_KEY)
#     )
#
#     return dataset
#
# # Vocabulary size and number of words in a sequence.
# VOCAB_SIZE      = 8000
# SEQUENCE_LENGTH = 100
#
# vectorize_layer = layers.TextVectorization(
#     standardize            = 'lower_and_strip_punctuation',
#     max_tokens             = VOCAB_SIZE,
#     output_mode            = 'int',
#     output_sequence_length = SEQUENCE_LENGTH
# )
#
# def model_builder(hp):
#     """Build keras tuner model"""
#     embedding_dim = hp.Int('embedding_dim', min_value=16, max_value=128, step=16)
#     lstm_units    = hp.Int('lstm_units', min_value=16, max_value=128, step=16)
#     num_layers    = hp.Choice('num_layers', values=[1, 2, 3])
#     dense_units   = hp.Int('dense_units', min_value=16, max_value=128, step=16)
#     dropout_rate = hp.Float('dropout_rate', min_value=0.1, max_value=0.5, step=0.1)
#     learning_rate = hp.Choice('learning_rate', values=[1e-1, 1e-2, 1e-3])
#
#     inputs = tf.keras.Input(shape=(1,), name=transformed_name(FEATURE_KEY), dtype=tf.string)
#
#     reshaped_narrative = tf.reshape(inputs, [-1])
#     x = vectorize_layer(reshaped_narrative)
#     x = layers.Embedding(VOCAB_SIZE, embedding_dim, name='embedding')(x)
#     x = layers.Bidirectional(layers.LSTM(lstm_units))(x)
#     for _ in range(num_layers):
#         x = layers.Dense(dense_units, activation='relu')(x)
#     x = layers.Dropout(dropout_rate)(x)
#     outputs = layers.Dense(1, activation='sigmoid')(x)
#
#     model = tf.keras.Model(inputs = inputs, outputs = outputs)
#     model.compile(
#         loss      = tf.keras.losses.BinaryCrossentropy(from_logits=True),
#         optimizer = tf.keras.optimizers.Adam(learning_rate),
#         metrics   = [tf.keras.metrics.BinaryAccuracy()]
#     )
#
#     model.summary()
#     return model
#
# TunerFnResult = NamedTuple('TunerFnResult', [
#     ('tuner', base_tuner.BaseTuner),
#     ('fit_kwargs', Dict[Text, Any]),
# ])
#
# early_stop_callback = tf.keras.callbacks.EarlyStopping(
#     monitor  = 'val_binary_accuracy',
#     mode     = 'max',
#     verbose  = 1,
#     patience = 2,
#     min_delta= 0,
#     baseline = 0.9,
#     restore_best_weights =True
# )
#
# def tuner_fn(fn_args: FnArgs) -> None:
#     # Load the transform output
#     tf_transform_output = tft.TFTransformOutput(fn_args.transform_graph_path)
#
#     # Create batches of data
#     train_set = input_fn(fn_args.train_files[0], tf_transform_output, 10)
#     val_set   = input_fn(fn_args.eval_files[0],  tf_transform_output, 10)
#
#     vectorize_layer.adapt(
#         [j[0].numpy()[0] for j in [
#             i[0][transformed_name(FEATURE_KEY)]
#                 for i in list(train_set)
#         ]]
#     )
#
#     # Build the model tuner
#     model_tuner = kt.Hyperband(
#         hypermodel   = lambda hp: model_builder(hp),
#         objective    = kt.Objective('val_binary_accuracy', direction='max'),
#         max_epochs   = 5,
#         factor       = 3,
#         directory    = 'dhadhan-pipeline',
#         project_name = 'spam_email_tuner',
#     )
#
#     model_tuner.oracle.max_trials = 3
#
#     return TunerFnResult(
#         tuner      = model_tuner,
#         fit_kwargs = {
#             'callbacks'        : [early_stop_callback],
#             'x'                : train_set,
#             'validation_data'  : val_set,
#             'steps_per_epoch'  : fn_args.train_steps,
#             'validation_steps' : fn_args.eval_steps
#         }
#     )

# %% [markdown]
# ## Create Module Training

# %%
module_train = os.path.join(DATA_ROOT, 'train.py')

# %%
# %%writefile {module_train}
# """
# Author: Ahmad Ramadhan
# Date: 2024-05-02
# This is the train.py module.
# Usage:
# - For training model
# """
# import os
# import tensorflow as tf
# import tensorflow_transform as tft
# from tensorflow.keras import layers
# from tfx.components.trainer.fn_args_utils import FnArgs
#
# LABEL_KEY   = "Category"
# FEATURE_KEY = "Message"
#
# def transformed_name(key):
#     """Renaming transformed features"""
#     return key + "_xf"
#
# def gzip_reader_fn(filenames):
#     """Loads compressed data"""
#     return tf.data.TFRecordDataset(filenames, compression_type='GZIP')
#
# def input_fn(file_pattern, tf_transform_output, num_epochs, batch_size=64) -> tf.data.Dataset:
#     """Get post_tranform feature & create batches of data"""
#
#     # Get post_transform feature spec
#     transform_feature_spec = (
#         tf_transform_output.transformed_feature_spec().copy()
#     )
#
#     # Create batches of data
#     dataset = tf.data.experimental.make_batched_features_dataset(
#         file_pattern = file_pattern,
#         batch_size   = batch_size,
#         features     = transform_feature_spec,
#         reader       = gzip_reader_fn,
#         num_epochs   = num_epochs,
#         label_key    = transformed_name(LABEL_KEY)
#     )
#
#     return dataset
#
# # Vocabulary size and number of words in a sequence
# VOCAB_SIZE      = 8000
# SEQUENCE_LENGTH = 100
# embedding_dim   = 16
#
# vectorize_layer = layers.TextVectorization(
#     standardize            = 'lower_and_strip_punctuation',
#     max_tokens             = VOCAB_SIZE,
#     output_mode            = 'int',
#     output_sequence_length = SEQUENCE_LENGTH
# )
#
# def model_builder(hp):
#     """Build machine learning model"""
#     inputs = tf.keras.Input(shape=(1,), name=transformed_name(FEATURE_KEY), dtype=tf.string)
#
#     reshaped_narrative = tf.reshape(inputs, [-1])
#     x = vectorize_layer(reshaped_narrative)
#     x = layers.Embedding(VOCAB_SIZE, hp['embedding_dim'], name='embedding')(x)
#     x = layers.Bidirectional(layers.LSTM(hp['lstm_units']))(x)
#     for _ in range(hp['num_layers']):
#         x = layers.Dense(hp['dense_units'], activation='relu')(x)
#     x = layers.Dropout(hp['dropout_rate'])(x)
#     outputs = layers.Dense(1, activation='sigmoid')(x)
#
#     model = tf.keras.Model(inputs = inputs, outputs = outputs)
#     model.compile(
#         loss      = tf.keras.losses.BinaryCrossentropy(from_logits=True),
#         optimizer = tf.keras.optimizers.Adam(hp['learning_rate']),
#         metrics   = [tf.keras.metrics.BinaryAccuracy()]
#     )
#
#     model.summary()
#     return model
#
# def _get_serve_tf_examples_fn(model, tf_transform_output):
#     model.tft_layer = tf_transform_output.transform_features_layer()
#
#     @tf.function
#     def serve_tf_examples_fn(serialized_tf_examples):
#         feature_spec = tf_transform_output.raw_feature_spec()
#         feature_spec.pop(LABEL_KEY)
#
#         parsed_features      = tf.io.parse_example(serialized_tf_examples, feature_spec)
#         transformed_features = model.tft_layer(parsed_features)
#
#         # get predictions using the transformed features
#         return model(transformed_features)
#
#     return serve_tf_examples_fn
#
# def run_fn(fn_args: FnArgs) -> None:
#     log_dir = os.path.join(os.path.dirname(fn_args.serving_model_dir), 'logs')
#     hp      = fn_args.hyperparameters['values']
#
#     tensorboard_callback = tf.keras.callbacks.TensorBoard(
#         log_dir = log_dir, update_freq='batch'
#     )
#
#     early_stop_callback = tf.keras.callbacks.EarlyStopping(
#         monitor  = 'val_binary_accuracy',
#         mode     = 'max',
#         verbose  = 1,
#         patience = 10
#     )
#
#     model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
#         fn_args.serving_model_dir,
#         monitor        = 'val_binary_accuracy',
#         mode           = 'max',
#         verbose        = 1,
#         save_best_only = True
#     )
#
#     callbacks = [
#         tensorboard_callback,
#         early_stop_callback,
#         model_checkpoint_callback
#     ]
#
#     # Load the transform output
#     tf_transform_output = tft.TFTransformOutput(fn_args.transform_graph_path)
#
#     # Create batches of data
#     train_set = input_fn(fn_args.train_files, tf_transform_output, hp['tuner/epochs'])
#     val_set   = input_fn(fn_args.eval_files,  tf_transform_output, hp['tuner/epochs'])
#
#     vectorize_layer.adapt(
#         [j[0].numpy()[0] for j in [
#             i[0][transformed_name(FEATURE_KEY)]
#                 for i in list(train_set)
#         ]]
#     )
#
#     # Build the model
#     model = model_builder(hp)
#
#     # Train the model
#     model.fit(
#         x                = train_set,
#         validation_data  = val_set,
#         callbacks        = callbacks,
#         steps_per_epoch  = fn_args.train_steps,
#         validation_steps = fn_args.eval_steps,
#         epochs           = hp['tuner/epochs']
#     )
#
#     signatures = {
#         'serving_default': _get_serve_tf_examples_fn(
#             model, tf_transform_output
#         ).get_concrete_function(
#             tf.TensorSpec(
#                 shape = [None],
#                 dtype = tf.string,
#                 name  = 'examples'
#             )
#         )
#     }
#
#     model.save(
#         fn_args.serving_model_dir,
#         save_format = 'tf',
#         signatures  = signatures
#     )
#
#     plot_model(
#         model,
#         to_file='images/model_plot.png',
#         show_shapes=True,
#         show_layer_names=True
#     )

# %% [markdown]
# ## Create Module local-pipeline

# %%
module_pipeline = os.path.join(DATA_ROOT, 'local-pipeline.py')

# %%
# %%writefile {module_train}
# """
# Author: Ahmad Ramadhan
# Date: 2024-05-02
# This is the local-pipeline.py module.
# Usage:
# - For running Components module with pipeline orchestrator: Apache Beam.
# """
# import os
# from typing import Text
#
# from absl import logging
# from tfx.orchestration import metadata, pipeline
# from tfx.orchestration.beam.beam_dag_runner import BeamDagRunner
#
# PIPELINE_NAME = 'diabetes-pipeline'
#
# DATA_ROOT = 'data'
# TRANSFORM_MODULE_FILE = 'modules/transform.py'
# TRAINER_MODULE_FILE = 'modules/trainer.py'
#
# OUTPUT_BASE = 'output'
# serving_model_dir = os.path.join(OUTPUT_BASE, 'serving_model')
# pipeline_root = os.path.join(OUTPUT_BASE, PIPELINE_NAME)
# metadata_path = os.path.join(pipeline_root, 'metadata.sqlite')
#
#
# def init_local_pipeline(
#     components, pipeline_root: Text
# ) -> pipeline.Pipeline:
#     """
#     Initialize a local TFX pipeline.
#
#     Args:
#         components: A dictionary of TFX components to be included in the pipeline.
#         pipeline_root: Root directory for pipeline output artifacts.
#
#     Returns:
#         A TFX pipeline.
#     """
#     logging.info(f'Pipeline root set to: {pipeline_root}')
#     beam_args = [
#         '--direct_running_mode=multi_processing'
#         # 0 auto-detect based on the number of CPUs available
#         # duraing execution time
#         '----direct_num_workers=0'
#     ]
#
#     return pipeline.Pipeline(
#         pipeline_name=PIPELINE_NAME,
#         pipeline_root=pipeline_root,
#         components=components,
#         enable_cache=True,
#         metadata_connection_config=metadata.sqlite_metadata_connection_config(
#             metadata_path
#         ),
#         eam_pipeline_args=beam_args
#     )
#
#
# if __name__ == '__main__':
#     logging.set_verbosity(logging.INFO)
#
#     from modules.components import init_components
#     components = init_components(
#         DATA_ROOT,
#         training_module=TRAINER_MODULE_FILE,
#         transform_module=TRANSFORM_MODULE_FILE,
#         training_steps=5000,
#         eval_steps=1000,
#         serving_model_dir=serving_model_dir,
#     )
#
#     pipeline = init_local_pipeline(components, pipeline_root)
#     BeamDagRunner().run(pipeline=pipeline)

# %% [markdown]
# # Load Data

# %%
os.environ['KAGGLE_USERNAME'] = 'ahrdadan'
os.environ['KAGGLE_KEY']      = '7eb307ba5bd108dae806763473bd568c'

# %%
# !kaggle datasets download -d ashfakyeafi/spam-email-classification -f email.csv
# Out:
# Dataset URL: https://www.kaggle.com/datasets/ashfakyeafi/spam-email-classification
# License(s): Apache 2.0
# Downloading email.csv to d:\#kuliah\Dicoding\tfx_python3.9
# 2024-05-01 03:00:34,621 WARNING Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLEOFError(8, 'EOF occurred in violation of protocol (_ssl.c:1129)'))': /api/v1/datasets/metadata/ashfakyeafi/spam-email-classification
# 2024-05-01 03:00:48,124 WARNING Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLEOFError(8, 'EOF occurred in violation of protocol (_ssl.c:1129)'))': /api/v1/datasets/metadata/ashfakyeafi/spam-email-classification
# 2024-05-01 03:00:51,585 WARNING Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLEOFError(8, 'EOF occurred in violation of protocol (_ssl.c:1129)'))': /api/v1/datasets/metadata/ashfakyeafi/spam-email-classification
#
#   0%|          | 0.00/469k [00:00<?, ?B/s]
# 100%|██████████| 469k/469k [00:01<00:00, 437kB/s]
# 100%|██████████| 469k/469k [00:01<00:00, 436kB/s]

# %%
DATA_PATH = 'dataset'

DATASET_NAME = 'email.csv'

if not os.path.exists(DATA_PATH):
    os.makedirs(DATA_PATH)

df = pd.read_csv(DATASET_NAME)

df['Category'] = df['Category'].map({'spam': 1, 'ham': 0})
df['Category'] = df['Category'].fillna(0)
df['Category'] = df['Category'].astype(int)

df.to_csv(os.path.join(DATA_PATH, DATASET_NAME), index=False)
df = pd.read_csv(f'{DATA_PATH}/{DATASET_NAME}')

os.remove(DATASET_NAME)

df.head()
# Out:
#    Category  \
# 0         0
# 1         0
# 2         1
# 3         0
# 4         0
#
#                                                                                                                                                        Message
# 0                                              Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...
# 1                                                                                                                                Ok lar... Joking wif u oni...
# 2  Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive entry question(std txt rate)T&C's apply 08452810075over18's
# 3                                                                                                            U dun say so early hor... U c already then say...
# 4                                                                                                Nah I don't think he goes to usf, he lives around here though

# %% [markdown]
# # Pipeline
# ---

# %% [markdown]
# Initial interactive context and directory

# %%
PIPELINE_NAME = 'dhadhan-pipeline'
SCHEMA_PIPELINE_NAME = 'spam-email-tfdv-schema'

PIPELINE_ROOT = os.path.join(PIPELINE_NAME)
METADATA_PATH = os.path.join('metadata', PIPELINE_NAME, 'metadata.db')

SERVING_MODEL_DIR = os.path.join('serving_model', PIPELINE_NAME)

DATA_ROOT = DATA_PATH

context = InteractiveContext(pipeline_root=PIPELINE_ROOT)
# Out:
# WARNING:absl:InteractiveContext metadata_connection_config not provided: using SQLite ML Metadata database at dhadhan-pipeline\metadata.sqlite.

# %% [markdown]
# ## Data Ingestion

# %%
output = example_gen_pb2.Output(
    split_config = example_gen_pb2.SplitConfig(splits=[
        example_gen_pb2.SplitConfig.Split(name='train', hash_buckets=3),
        example_gen_pb2.SplitConfig.Split(name='eval',  hash_buckets=1)
    ])
)

example_gen = CsvExampleGen(input_base=DATA_ROOT, output_config=output)

# %%
context.run(example_gen)
# Out:
# ExecutionResult(
#     component_id: CsvExampleGen
#     execution_id: 1
#     outputs:
#         examples: OutputChannel(artifact_type=Examples, producer_component_id=CsvExampleGen, output_key=examples, additional_properties={}, additional_custom_properties={}))

# %% [markdown]
# ## Data Validation

# %%
statistics_gen = StatisticsGen(
    examples = example_gen.outputs['examples']
)

context.run(statistics_gen)
# Out:
# Requirement already satisfied: absl-py==1.4.0 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 1)) (1.4.0)
# Requirement already satisfied: anyio==3.6.2 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 2)) (3.6.2)
# Requirement already satisfied: apache-beam==2.44.0 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 3)) (2.44.0)
# Requirement already satisfied: argon2-cffi==21.3.0 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 4)) (21.3.0)
# Requirement already satisfied: argon2-cffi-bindings==21.2.0 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 5)) (21.2.0)
# Requirement already satisfied: arrow==1.2.3 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 6)) (1.2.3)
# Requirement already satisfied: astunparse==1.6.3 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 7)) (1.6.3)
# Requirement already satisfied: attrs==21.4.0 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 8)) (21.4.0)
# Requirement already satisfied: backcall==0.2.0 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 9)) (0.2.0)
# Requirement already satisfied: beautifulsoup4==4.11.1 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 10)) (4.11.1)
# Requirement already satisfied: bleach==5.0.1 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 11)) (5.0.1)
# Requirement already satisfied: cachetools==4.2.4 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 12)) (4.2.4)
# Collecting certifi==2022.9.24 (from -r requirements.txt (line 13))
#   Using cached certifi-2022.9.24-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: cffi==1.16.0 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 14)) (1.16.0)
# Requirement already satisfied: charset-normalizer==3.3.2 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 15)) (3.3.2)
# Requirement already satisfied: click==7.1.2 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 16)) (7.1.2)
# Requirement already satisfied: cloudpickle==2.2.0 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 17)) (2.2.0)
# Requirement already satisfied: colorama==0.4.6 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 18)) (0.4.6)
# Requirement already satisfied: comm==0.1.2 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 19)) (0.1.2)
# Requirement already satisfied: crcmod==1.7 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 20)) (1.7)
# Requirement already satisfied: debugpy==1.6.5 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 21)) (1.6.5)
# Requirement already satisfied: decorator==5.1.1 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 22)) (5.1.1)
# Requirement already satisfied: defusedxml==0.7.1 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 23)) (0.7.1)
# Requirement already satisfied: dill==0.3.1.1 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 24)) (0.3.1.1)
# Requirement already satisfied: docker==4.4.4 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 25)) (4.4.4)
# Requirement already satisfied: docopt==0.6.2 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 26)) (0.6.2)
# Requirement already satisfied: entrypoints==0.4 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 27)) (0.4)
# Requirement already satisfied: fastavro==1.7.0 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 28)) (1.7.0)
# Requirement already satisfied: fasteners==0.18 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 29)) (0.18)
# Requirement already satisfied: fastjsonschema==2.16.2 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 30)) (2.16.2)
# Requirement already satisfied: Flask==2.0.3 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 31)) (2.0.3)
# Requirement already satisfied: flatbuffers==23.1.4 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 32)) (23.1.4)
# Requirement already satisfied: fqdn==1.5.1 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 33)) (1.5.1)
# Requirement already satisfied: gast==0.4.0 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 34)) (0.4.0)
# Requirement already satisfied: google-api-core==1.32.0 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 35)) (1.32.0)
# Requirement already satisfied: google-api-python-client==1.12.11 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 36)) (1.12.11)
# Requirement already satisfied: google-apitools==0.5.31 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 37)) (0.5.31)
# Requirement already satisfied: google-auth==1.35.0 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 38)) (1.35.0)
# Requirement already satisfied: google-auth-httplib2==0.1.0 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 39)) (0.1.0)
# Requirement already satisfied: google-auth-oauthlib==0.4.6 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 40)) (0.4.6)
# Requirement already satisfied: google-cloud-aiplatform==1.17.1 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 41)) (1.17.1)
# Requirement already satisfied: google-cloud-bigquery==2.34.4 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 42)) (2.34.4)
# Requirement already satisfied: google-cloud-bigquery-storage==2.13.2 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 43)) (2.13.2)
# Requirement already satisfied: google-cloud-bigtable==1.7.3 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 44)) (1.7.3)
# Requirement already satisfied: google-cloud-core==2.3.2 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 45)) (2.3.2)
# Requirement already satisfied: google-cloud-datastore==1.15.5 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 46)) (1.15.5)
# Requirement already satisfied: google-cloud-dlp==3.9.2 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 47)) (3.9.2)
# Requirement already satisfied: google-cloud-language==1.3.2 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 48)) (1.3.2)
# Requirement already satisfied: google-cloud-pubsub==2.13.11 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 49)) (2.13.11)
# Requirement already satisfied: google-cloud-pubsublite==1.6.0 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 50)) (1.6.0)
# Requirement already satisfied: google-cloud-recommendations-ai==0.7.1 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 51)) (0.7.1)
# Requirement already satisfied: google-cloud-resource-manager==1.6.3 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 52)) (1.6.3)
# Requirement already satisfied: google-cloud-spanner==3.26.0 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 53)) (3.26.0)
# Requirement already satisfied: google-cloud-storage==2.7.0 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 54)) (2.7.0)
# Requirement already satisfied: google-cloud-videointelligence==1.16.3 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 55)) (1.16.3)
# Requirement already satisfied: google-cloud-vision==3.1.4 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 56)) (3.1.4)
# Requirement already satisfied: google-crc32c==1.5.0 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 57)) (1.5.0)
# Requirement already satisfied: google-pasta==0.2.0 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 58)) (0.2.0)
# Requirement already satisfied: google-resumable-media==2.4.0 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 59)) (2.4.0)
# Requirement already satisfied: googleapis-common-protos==1.58.0 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 60)) (1.58.0)
# Requirement already satisfied: grpc-google-iam-v1==0.12.6 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 61)) (0.12.6)
# Requirement already satisfied: grpcio==1.51.1 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 62)) (1.51.1)
# Requirement already satisfied: grpcio-status==1.48.2 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 63)) (1.48.2)
# Requirement already satisfied: h5py==3.7.0 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 64)) (3.7.0)
# Requirement already satisfied: hdfs==2.7.0 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 65)) (2.7.0)
# Requirement already satisfied: httplib2==0.20.4 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 66)) (0.20.4)
# Requirement already satisfied: idna==3.7 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 67)) (3.7)
# Requirement already satisfied: importlib-metadata==6.0.0 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 68)) (6.0.0)
# Requirement already satisfied: importlib-resources==5.10.2 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 69)) (5.10.2)
# Requirement already satisfied: ipykernel==6.20.1 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 70)) (6.20.1)
# Requirement already satisfied: ipython==7.34.0 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 71)) (7.34.0)
# Requirement already satisfied: ipython-genutils==0.2.0 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 72)) (0.2.0)
# Requirement already satisfied: ipywidgets==7.7.2 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 73)) (7.7.2)
# Requirement already satisfied: isoduration==20.11.0 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 74)) (20.11.0)
# Requirement already satisfied: itsdangerous==2.1.2 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 75)) (2.1.2)
# Requirement already satisfied: jedi==0.18.2 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 76)) (0.18.2)
# Requirement already satisfied: Jinja2==3.1.2 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 77)) (3.1.2)
# Requirement already satisfied: joblib==1.2.0 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 78)) (1.2.0)
# Requirement already satisfied: jsonpointer==2.3 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 79)) (2.3)
# Requirement already satisfied: jsonschema==4.17.3 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 80)) (4.17.3)
# Requirement already satisfied: jupyter==1.0.0 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 81)) (1.0.0)
# Requirement already satisfied: jupyter-console==6.4.4 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 82)) (6.4.4)
# Requirement already satisfied: jupyter-events==0.6.3 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 83)) (0.6.3)
# Requirement already satisfied: jupyter_client==7.4.9 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 84)) (7.4.9)
# Requirement already satisfied: jupyter_core==5.1.3 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 85)) (5.1.3)
# Requirement already satisfied: jupyter_server==2.1.0 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 86)) (2.1.0)
# Requirement already satisfied: jupyter_server_terminals==0.4.4 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 87)) (0.4.4)
# Requirement already satisfied: jupyterlab-pygments==0.2.2 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 88)) (0.2.2)
# Requirement already satisfied: jupyterlab-widgets==1.1.1 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 89)) (1.1.1)
# Requirement already satisfied: keras==2.10.0 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 90)) (2.10.0)
# Requirement already satisfied: Keras-Preprocessing==1.1.2 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 91)) (1.1.2)
# Requirement already satisfied: keras-tuner==1.1.3 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 92)) (1.1.3)
# Requirement already satisfied: kt-legacy==1.0.4 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 93)) (1.0.4)
# Requirement already satisfied: kubernetes==12.0.1 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 94)) (12.0.1)
# Requirement already satisfied: libclang==15.0.6.1 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 95)) (15.0.6.1)
# Requirement already satisfied: Markdown==3.4.1 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 96)) (3.4.1)
# Requirement already satisfied: MarkupSafe==2.1.1 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 97)) (2.1.1)
# Requirement already satisfied: matplotlib-inline==0.1.6 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 98)) (0.1.6)
# Requirement already satisfied: mistune==2.0.4 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 99)) (2.0.4)
# Requirement already satisfied: ml-metadata==1.11.0 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 100)) (1.11.0)
# Requirement already satisfied: ml-pipelines-sdk==1.11.0 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 101)) (1.11.0)
# Requirement already satisfied: nbclassic==0.4.8 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 102)) (0.4.8)
# Requirement already satisfied: nbclient==0.7.2 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 103)) (0.7.2)
# Requirement already satisfied: nbconvert==7.2.7 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 104)) (7.2.7)
# Requirement already satisfied: nbformat==5.7.3 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 105)) (5.7.3)
# Requirement already satisfied: nest-asyncio==1.5.6 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 106)) (1.5.6)
# Requirement already satisfied: notebook==6.5.2 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 107)) (6.5.2)
# Requirement already satisfied: notebook_shim==0.2.2 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 108)) (0.2.2)
# Requirement already satisfied: numpy==1.22.4 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 109)) (1.22.4)
# Requirement already satisfied: oauth2client==4.1.3 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 110)) (4.1.3)
# Requirement already satisfied: oauthlib==3.2.2 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 111)) (3.2.2)
# Requirement already satisfied: objsize==0.6.1 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 112)) (0.6.1)
# Requirement already satisfied: opt-einsum==3.3.0 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 113)) (3.3.0)
# Requirement already satisfied: orjson==3.8.5 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 114)) (3.8.5)
# Requirement already satisfied: overrides==6.5.0 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 115)) (6.5.0)
# Requirement already satisfied: packaging==20.9 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 116)) (20.9)
# Requirement already satisfied: pandas==1.5.2 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 117)) (1.5.2)
# Requirement already satisfied: pandocfilters==1.5.0 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 118)) (1.5.0)
# Requirement already satisfied: parso==0.8.3 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 119)) (0.8.3)
# Requirement already satisfied: pexpect==4.8.0 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 120)) (4.8.0)
# Requirement already satisfied: pickleshare==0.7.5 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 121)) (0.7.5)
# Requirement already satisfied: pkgutil_resolve_name==1.3.10 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 122)) (1.3.10)
# Requirement already satisfied: platformdirs==2.6.2 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 123)) (2.6.2)
# Requirement already satisfied: portpicker==1.5.2 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 124)) (1.5.2)
# Requirement already satisfied: prometheus-client==0.15.0 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 125)) (0.15.0)
# Requirement already satisfied: prompt-toolkit==3.0.36 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 126)) (3.0.36)
# Requirement already satisfied: proto-plus==1.22.2 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 127)) (1.22.2)
# Requirement already satisfied: protobuf==3.19.6 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 128)) (3.19.6)
# Requirement already satisfied: psutil==5.9.4 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 129)) (5.9.4)
# Requirement already satisfied: ptyprocess==0.7.0 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 130)) (0.7.0)
# Requirement already satisfied: pyarrow==6.0.1 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 131)) (6.0.1)
# Requirement already satisfied: pyasn1==0.4.8 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 132)) (0.4.8)
# Requirement already satisfied: pyasn1-modules==0.2.8 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 133)) (0.2.8)
# Requirement already satisfied: pycparser==2.22 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 134)) (2.22)
# Requirement already satisfied: pydot==1.4.2 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 135)) (1.4.2)
# Requirement already satisfied: pyfarmhash==0.3.2 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 136)) (0.3.2)
# Requirement already satisfied: Pygments==2.14.0 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 137)) (2.14.0)
# Requirement already satisfied: pymongo==3.13.0 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 138)) (3.13.0)
# Requirement already satisfied: pyparsing==3.0.9 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 139)) (3.0.9)
# Requirement already satisfied: pyrsistent==0.19.3 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 140)) (0.19.3)
# Requirement already satisfied: python-dateutil==2.8.2 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 141)) (2.8.2)
# Requirement already satisfied: python-json-logger==2.0.4 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 142)) (2.0.4)
# Requirement already satisfied: pytz==2022.7.1 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 143)) (2022.7.1)
# Requirement already satisfied: pywin32==227 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 144)) (227)
# Requirement already satisfied: pywinpty==2.0.13 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 145)) (2.0.13)
# Requirement already satisfied: PyYAML==5.4.1 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 146)) (5.4.1)
# Requirement already satisfied: pyzmq==25.0.0 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 147)) (25.0.0)
# Requirement already satisfied: qtconsole==5.4.0 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 148)) (5.4.0)
# Requirement already satisfied: QtPy==2.3.0 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 149)) (2.3.0)
# Requirement already satisfied: regex==2022.10.31 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 150)) (2022.10.31)
# Requirement already satisfied: requests==2.31.0 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 151)) (2.31.0)
# Requirement already satisfied: requests-oauthlib==1.3.1 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 152)) (1.3.1)
# Requirement already satisfied: rfc3339-validator==0.1.4 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 153)) (0.1.4)
# Requirement already satisfied: rfc3986-validator==0.1.1 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 154)) (0.1.1)
# Requirement already satisfied: rsa==4.9 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 155)) (4.9)
# Requirement already satisfied: scikit-learn==1.2.0 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 156)) (1.2.0)
# Requirement already satisfied: scipy==1.10.0 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 157)) (1.10.0)
# Requirement already satisfied: Send2Trash==1.8.0 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 158)) (1.8.0)
# Requirement already satisfied: six==1.16.0 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 159)) (1.16.0)
# Requirement already satisfied: sniffio==1.3.0 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 160)) (1.3.0)
# Requirement already satisfied: soupsieve==2.3.2.post1 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 161)) (2.3.2.post1)
# Requirement already satisfied: sqlparse==0.4.3 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 162)) (0.4.3)
# Requirement already satisfied: tensorboard==2.10.1 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 163)) (2.10.1)
# Requirement already satisfied: tensorboard-data-server==0.6.1 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 164)) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit==1.8.1 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 165)) (1.8.1)
# Requirement already satisfied: tensorflow==2.10.1 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 166)) (2.10.1)
# Requirement already satisfied: tensorflow-data-validation==1.11.0 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 167)) (1.11.0)
# Requirement already satisfied: tensorflow-estimator==2.10.0 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 168)) (2.10.0)
# Requirement already satisfied: tensorflow-hub==0.12.0 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 169)) (0.12.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem==0.29.0 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 170)) (0.29.0)
# Requirement already satisfied: tensorflow-metadata==1.11.0 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 171)) (1.11.0)
# Requirement already satisfied: tensorflow-model-analysis==0.42.0 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 172)) (0.42.0)
# Requirement already satisfied: tensorflow-serving-api==2.10.1 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 173)) (2.10.1)
# Requirement already satisfied: tensorflow-transform==1.11.0 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 174)) (1.11.0)
# Requirement already satisfied: termcolor==2.2.0 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 175)) (2.2.0)
# Requirement already satisfied: terminado==0.17.1 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 176)) (0.17.1)
# Requirement already satisfied: tfx==1.11.0 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 177)) (1.11.0)
# Requirement already satisfied: tfx-bsl==1.11.0 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 178)) (1.11.0)
# Requirement already satisfied: threadpoolctl==3.1.0 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 179)) (3.1.0)
# Requirement already satisfied: tinycss2==1.2.1 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 180)) (1.2.1)
# Requirement already satisfied: tornado==6.2 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 181)) (6.2)
# Requirement already satisfied: traitlets==5.8.1 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 182)) (5.8.1)
# Requirement already satisfied: typing_extensions==4.4.0 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 183)) (4.4.0)
# Requirement already satisfied: uri-template==1.2.0 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 184)) (1.2.0)
# Requirement already satisfied: uritemplate==3.0.1 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 185)) (3.0.1)
# Requirement already satisfied: urllib3==2.2.1 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 186)) (2.2.1)
# Requirement already satisfied: wcwidth==0.2.6 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 187)) (0.2.6)
# Requirement already satisfied: webcolors==1.12 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 188)) (1.12)
# Requirement already satisfied: webencodings==0.5.1 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 189)) (0.5.1)
# Requirement already satisfied: websocket-client==1.4.2 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 190)) (1.4.2)
# Requirement already satisfied: Werkzeug==2.2.2 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 191)) (2.2.2)
# Requirement already satisfied: widgetsnbextension==3.6.1 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 192)) (3.6.1)
# Requirement already satisfied: wrapt==1.14.1 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 193)) (1.14.1)
# Requirement already satisfied: zipp==3.11.0 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 194)) (3.11.0)
# Requirement already satisfied: zstandard==0.19.0 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from -r requirements.txt (line 195)) (0.19.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from astunparse==1.6.3->-r requirements.txt (line 7)) (0.43.0)
# Requirement already satisfied: setuptools>=40.3.0 in d:\#kuliah\dicoding\tfx_python3.9\.venv\lib\site-packages (from google-api-core==1.32.0->-r requirements.txt (line 35)) (58.1.0)
# Using cached certifi-2022.9.24-py3-none-any.whl (161 kB)
# Installing collected packages: certifi
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2024.2.2
#     Uninstalling certifi-2024.2.2:
#       Successfully uninstalled certifi-2024.2.2
# Successfully installed certifi-2022.9.24
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLEOFError(8, 'EOF occurred in violation of protocol (_ssl.c:1129)'))': /simple/certifi/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLEOFError(8, 'EOF occurred in violation of protocol (_ssl.c:1129)'))': /simple/certifi/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLEOFError(8, 'EOF occurred in violation of protocol (_ssl.c:1129)'))': /simple/certifi/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLEOFError(8, 'EOF occurred in violation of protocol (_ssl.c:1129)'))': /simple/certifi/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLEOFError(8, 'EOF occurred in violation of protocol (_ssl.c:1129)'))': /simple/certifi/
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# kaggle 1.6.12 requires certifi>=2023.7.22, but you have certifi 2022.9.24 which is incompatible.
# ExecutionResult(
#     component_id: StatisticsGen
#     execution_id: 2
#     outputs:
#         statistics: OutputChannel(artifact_type=ExampleStatistics, producer_component_id=StatisticsGen, output_key=statistics, additional_properties={}, additional_custom_properties={}))

# %% [markdown]
# ### Buat data summary dengan statistic

# %%
context.show(statistics_gen.outputs["statistics"])
# Out:
# <b>Artifact at dhadhan-pipeline\StatisticsGen\statistics\2</b><br/><br/>
# <style>html[theme=dark] iframe {background: white;}</style>
# <div><b>'train' split:</b></div><br/>
# <iframe id='facets-iframe' width="100%" height="500px"></iframe>
#         <script>
#         facets_iframe = document.getElementById('facets-iframe');
#         facets_html = '<script src="https://cdnjs.cloudflare.com/ajax/libs/webcomponentsjs/1.3.3/webcomponents-lite.js"><\/script><link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/master/facets-dist/facets-jupyter.html"><facets-overview proto-input="..."></facets-overview>';
#         facets_iframe.srcdoc = facets_html;
#          facets_iframe.id = "";
#          setTimeout(() => {
#            facets_iframe.setAttribute('height', facets_iframe.contentWindow.document.body.offsetHeight + 'px')
#          }, 1500)
#          </script>
# <div><b>'eval' split:</b></div><br/>
# <iframe id='facets-iframe' width="100%" height="500px"></iframe>
#         <script>
#         facets_iframe = document.getElementById('facets-iframe');
#         facets_html = '<script src="https://cdnjs.cloudflare.com/ajax/libs/webcomponentsjs/1.3.3/webcomponents-lite.js"><\/script><link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/master/facets-dist/facets-jupyter.html"><facets-overview proto-input="..."></facets-overview>';
#         facets_iframe.srcdoc = facets_html;
#          facets_iframe.id = "";
#          setTimeout(() => {
#            facets_iframe.setAttribute('height', facets_iframe.contentWindow.document.body.offsetHeight + 'px')
#          }, 1500)
#          </script>

# %% [markdown]
# ### Membuat data schema

# %%
schema_gen = SchemaGen(
    statistics = statistics_gen.outputs['statistics']
)

context.run(schema_gen)
# Out:
# ExecutionResult(
#     component_id: SchemaGen
#     execution_id: 3
#     outputs:
#         schema: OutputChannel(artifact_type=Schema, producer_component_id=SchemaGen, output_key=schema, additional_properties={}, additional_custom_properties={}))

# %%
context.show(schema_gen.outputs['schema'])
# Out:
# <b>Artifact at dhadhan-pipeline\SchemaGen\schema\3</b><br/><br/>
#                Type  Presence Valency Domain
# Feature name
# 'Category'      INT  required              -
# 'Message'     BYTES  required              -

# %% [markdown]
# ### Check Anomali pada dataset

# %%
example_validator = ExampleValidator(
    statistics = statistics_gen.outputs['statistics'],
    schema     = schema_gen.outputs['schema']
)

context.run(example_validator)
# Out:
# ExecutionResult(
#     component_id: ExampleValidator
#     execution_id: 4
#     outputs:
#         anomalies: OutputChannel(artifact_type=ExampleAnomalies, producer_component_id=ExampleValidator, output_key=anomalies, additional_properties={}, additional_custom_properties={}))

# %%
context.show(example_validator.outputs['anomalies'])
# Out:
# <b>Artifact at dhadhan-pipeline\ExampleValidator\anomalies\4</b><br/><br/>
# <div><b>'train' split:</b></div><br/>
# <h4 style="color:green;">No anomalies found.</h4>
# <div><b>'eval' split:</b></div><br/>
# <h4 style="color:green;">No anomalies found.</h4>

# %% [markdown]
# ## Data Preprocessing
# Data preprocessing dengan module transform

# %%
TRANSFORM_MODULE_FILE = 'spam_email_transform.py'

# %%
# %%writefile {TRANSFORM_MODULE_FILE}
# import tensorflow as tf
#
# LABEL_KEY   = "Category"
# FEATURE_KEY = "Message"
#
# # Renaming transformed features
# def transformed_name(key):
#     return key + "_xf"
#
# # Preprocess input features into transformed features
# def preprocessing_fn(inputs):
#     """
#     inputs:  map from feature keys to raw features
#     outputs: map from feature keys to transformed features
#     """
#
#     outputs = {}
#     outputs[transformed_name(FEATURE_KEY)] = tf.strings.lower(inputs[FEATURE_KEY])
#     outputs[transformed_name(LABEL_KEY)]   = tf.cast(inputs[LABEL_KEY], tf.int64)
#
#     return outputs
# Out:
# Overwriting spam_email_transform.py

# %%
transform = Transform(
    examples    = example_gen.outputs['examples'],
    schema      = schema_gen.outputs['schema'],
    module_file = os.path.abspath(TRANSFORM_MODULE_FILE)
)

context.run(transform)
# Out:
# WARNING:root:This output type hint will be ignored and not used for type-checking purposes. Typically, output type hints for a PTransform are single (or nested) types wrapped by a PCollection, PDone, or None. Got: Tuple[Dict[<class 'str'>, Union[<class 'NoneType'>, <class 'tfx.components.transform.executor._Dataset'>]], Union[<class 'NoneType'>, Dict[<class 'str'>, Dict[<class 'str'>, <class 'apache_beam.pvalue.PCollection'>]]], <class 'int'>] instead.
# WARNING:root:This output type hint will be ignored and not used for type-checking purposes. Typically, output type hints for a PTransform are single (or nested) types wrapped by a PCollection, PDone, or None. Got: Tuple[Dict[<class 'str'>, Union[<class 'NoneType'>, <class 'tfx.components.transform.executor._Dataset'>]], Union[<class 'NoneType'>, Dict[<class 'str'>, Dict[<class 'str'>, <class 'apache_beam.pvalue.PCollection'>]]], <class 'int'>] instead.
# INFO:tensorflow:Assets written to: dhadhan-pipeline\Transform\transform_graph\5\.temp_path\tftransform_tmp\cf7263c5cbf24c57a883dc0374a1f7eb\assets
# INFO:tensorflow:Assets written to: dhadhan-pipeline\Transform\transform_graph\5\.temp_path\tftransform_tmp\cf7263c5cbf24c57a883dc0374a1f7eb\assets
# INFO:tensorflow:struct2tensor is not available.
# INFO:tensorflow:struct2tensor is not available.
# INFO:tensorflow:tensorflow_decision_forests is not available.
# INFO:tensorflow:tensorflow_decision_forests is not available.
# INFO:tensorflow:tensorflow_text is not available.
# INFO:tensorflow:tensorflow_text is not available.
# INFO:tensorflow:struct2tensor is not available.
# INFO:tensorflow:struct2tensor is not available.
# INFO:tensorflow:tensorflow_decision_forests is not available.
# INFO:tensorflow:tensorflow_decision_forests is not available.
# INFO:tensorflow:tensorflow_text is not available.
# INFO:tensorflow:tensorflow_text is not available.
# ExecutionResult(
#     component_id: Transform
#     execution_id: 5
#     outputs:
#         transform_graph: OutputChannel(artifact_type=TransformGraph, producer_component_id=Transform, output_key=transform_graph, additional_properties={}, additional_custom_properties={})
#         transformed_examples: OutputChannel(artifact_type=Examples, producer_component_id=Transform, output_key=transformed_examples, additional_properties={}, additional_custom_properties={})
#         updated_analyzer_cache: OutputChannel(artifact_type=TransformCache, producer_component_id=Transform, output_key=updated_analyzer_cache, additional_properties={}, additional_custom_properties={})
#         pre_transform_schema: OutputChannel(artifact_type=Schema, producer_component_id=Transform, output_key=pre_transform_schema, additional_properties={}, additional_custom_properties={})
#         pre_transform_stats: OutputChannel(artifact_type=ExampleStatistics, producer_component_id=Transform, output_key=pre_transform_stats, additional_properties={}, additional_custom_properties={})
#         post_transform_schema: OutputChannel(artifact_type=Schema, producer_component_id=Transform, output_key=post_transform_schema, additional_properties={}, additional_custom_properties={})
#         post_transform_stats: OutputChannel(artifact_type=ExampleStatistics, producer_component_id=Transform, output_key=post_transform_stats, additional_properties={}, additional_custom_properties={})
#         post_transform_anomalies: OutputChannel(artifact_type=ExampleAnomalies, producer_component_id=Transform, output_key=post_transform_anomalies, additional_properties={}, additional_custom_properties={}))

# %% [markdown]
# ## Tuning Model

# %%
TUNER_MODULE_FILE = 'spam_email_tuner.py'

# %%
# %%writefile {TUNER_MODULE_FILE}
# """
# Author: Ahmad Ramadhan
# Date: 2024-05-02
# This is the transform.py module.
# Usage:
# - COMPONENTS TFX PIPELINE
# """
# import os
# import tensorflow as tf
# import tensorflow_transform as tft
# import keras_tuner as kt
# from tensorflow.keras import layers
# from tfx.components.trainer.fn_args_utils import FnArgs
# from keras_tuner.engine import base_tuner
# from typing import NamedTuple, Dict, Text, Any
#
# LABEL_KEY   = "Category"
# FEATURE_KEY = "Message"
#
# def transformed_name(key):
#     """Renaming transformed features"""
#     return key + "_xf"
#
# def gzip_reader_fn(filenames):
#     """Loads compressed data"""
#     return tf.data.TFRecordDataset(filenames, compression_type='GZIP')
#
# def input_fn(file_pattern, tf_transform_output, num_epochs, batch_size=64) -> tf.data.Dataset:
#     """Get post_tranform feature & create batches of data"""
#
#     # Get post_transform feature spec
#     transform_feature_spec = (
#         tf_transform_output.transformed_feature_spec().copy()
#     )
#
#     # create batches of data
#     dataset = tf.data.experimental.make_batched_features_dataset(
#         file_pattern = file_pattern,
#         batch_size   = batch_size,
#         features     = transform_feature_spec,
#         reader       = gzip_reader_fn,
#         num_epochs   = num_epochs,
#         label_key    = transformed_name(LABEL_KEY)
#     )
#
#     return dataset
#
# # Vocabulary size and number of words in a sequence.
# VOCAB_SIZE      = 8000
# SEQUENCE_LENGTH = 100
#
# vectorize_layer = layers.TextVectorization(
#     standardize            = 'lower_and_strip_punctuation',
#     max_tokens             = VOCAB_SIZE,
#     output_mode            = 'int',
#     output_sequence_length = SEQUENCE_LENGTH
# )
#
# def model_builder(hp):
#     """Build keras tuner model"""
#     embedding_dim = hp.Int('embedding_dim', min_value=16, max_value=128, step=16)
#     lstm_units    = hp.Int('lstm_units', min_value=16, max_value=128, step=16)
#     num_layers    = hp.Choice('num_layers', values=[1, 2, 3])
#     dense_units   = hp.Int('dense_units', min_value=16, max_value=128, step=16)
#     dropout_rate = hp.Float('dropout_rate', min_value=0.1, max_value=0.5, step=0.1)
#     learning_rate = hp.Choice('learning_rate', values=[1e-1, 1e-2, 1e-3])
#
#     inputs = tf.keras.Input(shape=(1,), name=transformed_name(FEATURE_KEY), dtype=tf.string)
#
#     reshaped_narrative = tf.reshape(inputs, [-1])
#     x = vectorize_layer(reshaped_narrative)
#     x = layers.Embedding(VOCAB_SIZE, embedding_dim, name='embedding')(x)
#     x = layers.Bidirectional(layers.LSTM(lstm_units))(x)
#     for _ in range(num_layers):
#         x = layers.Dense(dense_units, activation='relu')(x)
#     x = layers.Dropout(dropout_rate)(x)
#     outputs = layers.Dense(1, activation='sigmoid')(x)
#
#     model = tf.keras.Model(inputs = inputs, outputs = outputs)
#     model.compile(
#         loss      = tf.keras.losses.BinaryCrossentropy(from_logits=True),
#         optimizer = tf.keras.optimizers.Adam(learning_rate),
#         metrics   = [tf.keras.metrics.BinaryAccuracy()]
#     )
#
#     model.summary()
#     return model
#
# TunerFnResult = NamedTuple('TunerFnResult', [
#     ('tuner', base_tuner.BaseTuner),
#     ('fit_kwargs', Dict[Text, Any]),
# ])
#
# early_stop_callback = tf.keras.callbacks.EarlyStopping(
#     monitor  = 'val_binary_accuracy',
#     mode     = 'max',
#     verbose  = 1,
#     patience = 2,
#     min_delta= 0,
#     baseline = 0.9,
#     restore_best_weights =True
# )
#
# def tuner_fn(fn_args: FnArgs) -> None:
#     # Load the transform output
#     tf_transform_output = tft.TFTransformOutput(fn_args.transform_graph_path)
#
#     # Create batches of data
#     train_set = input_fn(fn_args.train_files[0], tf_transform_output, 10)
#     val_set   = input_fn(fn_args.eval_files[0],  tf_transform_output, 10)
#
#     vectorize_layer.adapt(
#         [j[0].numpy()[0] for j in [
#             i[0][transformed_name(FEATURE_KEY)]
#                 for i in list(train_set)
#         ]]
#     )
#
#     # Build the model tuner
#     model_tuner = kt.Hyperband(
#         hypermodel   = lambda hp: model_builder(hp),
#         objective    = kt.Objective('val_binary_accuracy', direction='max'),
#         max_epochs   = 5,
#         factor       = 3,
#         directory    = 'dhadhan-pipeline',
#         project_name = 'spam_email_tuner',
#     )
#
#     model_tuner.oracle.max_trials = 3
#
#     return TunerFnResult(
#         tuner      = model_tuner,
#         fit_kwargs = {
#             'callbacks'        : [early_stop_callback],
#             'x'                : train_set,
#             'validation_data'  : val_set,
#             'steps_per_epoch'  : fn_args.train_steps,
#             'validation_steps' : fn_args.eval_steps
#         }
#     )
# Out:
# Overwriting spam_email_tuner.py

# %%
tuner = Tuner(
    module_file     = os.path.abspath(TUNER_MODULE_FILE),
    examples        = transform.outputs['transformed_examples'],
    transform_graph = transform.outputs['transform_graph'],
    schema          = schema_gen.outputs['schema'],
    train_args      = trainer_pb2.TrainArgs(splits=['train']),
    eval_args       = trainer_pb2.EvalArgs(splits=['eval'])
)


context.run(tuner)
# Out:
# Trial 3 Complete [00h 11m 48s]
# val_binary_accuracy: 0.9817813634872437
#
# Best val_binary_accuracy So Far: 0.9817813634872437
# Total elapsed time: 00h 17m 58s
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# Results summary
# Results in dhadhan-pipeline\spam_email_tuner
# Showing 10 best trials
# <keras_tuner.engine.objective.Objective object at 0x0000023B27E09A90>
# Trial summary
# Hyperparameters:
# embedding_dim: 32
# lstm_units: 96
# num_layers: 2
# dense_units: 48
# dropout_rate: 0.5
# learning_rate: 0.001
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 1
# tuner/round: 0
# Score: 0.9817813634872437
# Trial summary
# Hyperparameters:
# embedding_dim: 64
# lstm_units: 64
# num_layers: 2
# dense_units: 48
# dropout_rate: 0.4
# learning_rate: 0.001
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 1
# tuner/round: 0
# Score: 0.980431854724884
# Trial summary
# Hyperparameters:
# embedding_dim: 64
# lstm_units: 32
# num_layers: 3
# dense_units: 96
# dropout_rate: 0.4
# learning_rate: 0.001
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 1
# tuner/round: 0
# Score: 0.97773277759552
# ExecutionResult(
#     component_id: Tuner
#     execution_id: 9
#     outputs:
#         best_hyperparameters: OutputChannel(artifact_type=HyperParameters, producer_component_id=Tuner, output_key=best_hyperparameters, additional_properties={}, additional_custom_properties={})
#         tuner_results: OutputChannel(artifact_type=TunerResults, producer_component_id=Tuner, output_key=tuner_results, additional_properties={}, additional_custom_properties={}))

# %% [markdown]
# ## Model Training

# %%
TRAINER_MODULE_FILE = "spam_email_trainer.py"

# %%
# %%writefile {TRAINER_MODULE_FILE}
# import os
# import tensorflow as tf
# import tensorflow_transform as tft
# from tensorflow.keras import layers
# from tfx.components.trainer.fn_args_utils import FnArgs
#
# LABEL_KEY   = "Category"
# FEATURE_KEY = "Message"
#
# def transformed_name(key):
#     """Renaming transformed features"""
#     return key + "_xf"
#
# def gzip_reader_fn(filenames):
#     """Loads compressed data"""
#     return tf.data.TFRecordDataset(filenames, compression_type='GZIP')
#
# def input_fn(file_pattern, tf_transform_output, num_epochs, batch_size=64) -> tf.data.Dataset:
#     """Get post_tranform feature & create batches of data"""
#
#     # Get post_transform feature spec
#     transform_feature_spec = (
#         tf_transform_output.transformed_feature_spec().copy()
#     )
#
#     # Create batches of data
#     dataset = tf.data.experimental.make_batched_features_dataset(
#         file_pattern = file_pattern,
#         batch_size   = batch_size,
#         features     = transform_feature_spec,
#         reader       = gzip_reader_fn,
#         num_epochs   = num_epochs,
#         label_key    = transformed_name(LABEL_KEY)
#     )
#
#     return dataset
#
# # Vocabulary size and number of words in a sequence
# VOCAB_SIZE      = 8000
# SEQUENCE_LENGTH = 100
# embedding_dim   = 16
#
# vectorize_layer = layers.TextVectorization(
#     standardize            = 'lower_and_strip_punctuation',
#     max_tokens             = VOCAB_SIZE,
#     output_mode            = 'int',
#     output_sequence_length = SEQUENCE_LENGTH
# )
#
# def model_builder(hp):
#     """Build machine learning model"""
#     inputs = tf.keras.Input(shape=(1,), name=transformed_name(FEATURE_KEY), dtype=tf.string)
#
#     reshaped_narrative = tf.reshape(inputs, [-1])
#     x = vectorize_layer(reshaped_narrative)
#     x = layers.Embedding(VOCAB_SIZE, hp['embedding_dim'], name='embedding')(x)
#     x = layers.Bidirectional(layers.LSTM(hp['lstm_units']))(x)
#     for _ in range(hp['num_layers']):
#         x = layers.Dense(hp['dense_units'], activation='relu')(x)
#     x = layers.Dropout(hp['dropout_rate'])(x)
#     outputs = layers.Dense(1, activation='sigmoid')(x)
#
#     model = tf.keras.Model(inputs = inputs, outputs = outputs)
#     model.compile(
#         loss      = tf.keras.losses.BinaryCrossentropy(from_logits=True),
#         optimizer = tf.keras.optimizers.Adam(hp['learning_rate']),
#         metrics   = [tf.keras.metrics.BinaryAccuracy()]
#     )
#
#     model.summary()
#     return model
#
# def _get_serve_tf_examples_fn(model, tf_transform_output):
#     model.tft_layer = tf_transform_output.transform_features_layer()
#
#     @tf.function
#     def serve_tf_examples_fn(serialized_tf_examples):
#         feature_spec = tf_transform_output.raw_feature_spec()
#         feature_spec.pop(LABEL_KEY)
#
#         parsed_features      = tf.io.parse_example(serialized_tf_examples, feature_spec)
#         transformed_features = model.tft_layer(parsed_features)
#
#         # get predictions using the transformed features
#         return model(transformed_features)
#
#     return serve_tf_examples_fn
#
# def run_fn(fn_args: FnArgs) -> None:
#     log_dir = os.path.join(os.path.dirname(fn_args.serving_model_dir), 'logs')
#     hp      = fn_args.hyperparameters['values']
#
#     tensorboard_callback = tf.keras.callbacks.TensorBoard(
#         log_dir = log_dir, update_freq='batch'
#     )
#
#     early_stop_callback = tf.keras.callbacks.EarlyStopping(
#         monitor  = 'val_binary_accuracy',
#         mode     = 'max',
#         verbose  = 1,
#         patience = 10
#     )
#
#     model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
#         fn_args.serving_model_dir,
#         monitor        = 'val_binary_accuracy',
#         mode           = 'max',
#         verbose        = 1,
#         save_best_only = True
#     )
#
#     callbacks = [
#         tensorboard_callback,
#         early_stop_callback,
#         model_checkpoint_callback
#     ]
#
#     # Load the transform output
#     tf_transform_output = tft.TFTransformOutput(fn_args.transform_graph_path)
#
#     # Create batches of data
#     train_set = input_fn(fn_args.train_files, tf_transform_output, hp['tuner/epochs'])
#     val_set   = input_fn(fn_args.eval_files,  tf_transform_output, hp['tuner/epochs'])
#
#     vectorize_layer.adapt(
#         [j[0].numpy()[0] for j in [
#             i[0][transformed_name(FEATURE_KEY)]
#                 for i in list(train_set)
#         ]]
#     )
#
#     # Build the model
#     model = model_builder(hp)
#
#     # Train the model
#     model.fit(
#         x                = train_set,
#         validation_data  = val_set,
#         callbacks        = callbacks,
#         steps_per_epoch  = fn_args.train_steps,
#         validation_steps = fn_args.eval_steps,
#         epochs           = hp['tuner/epochs']
#     )
#
#     signatures = {
#         'serving_default': _get_serve_tf_examples_fn(
#             model, tf_transform_output
#         ).get_concrete_function(
#             tf.TensorSpec(
#                 shape = [None],
#                 dtype = tf.string,
#                 name  = 'examples'
#             )
#         )
#     }
#
#     model.save(
#         fn_args.serving_model_dir,
#         save_format = 'tf',
#         signatures  = signatures
#     )
# Out:
# Overwriting spam_email_trainer.py

# %%
trainer = Trainer(
    module_file     = os.path.abspath(TRAINER_MODULE_FILE),
    examples        = transform.outputs['transformed_examples'],
    transform_graph = transform.outputs['transform_graph'],
    schema          = schema_gen.outputs['schema'],
    hyperparameters = tuner.outputs['best_hyperparameters'],
    train_args      = trainer_pb2.TrainArgs(splits=['train']),
    eval_args       = trainer_pb2.EvalArgs(splits=['eval'])
)

context.run(trainer)
# Out:
# WARNING:absl:Examples artifact does not have payload_format custom property. Falling back to FORMAT_TF_EXAMPLE
# WARNING:absl:Examples artifact does not have payload_format custom property. Falling back to FORMAT_TF_EXAMPLE
# WARNING:absl:Examples artifact does not have payload_format custom property. Falling back to FORMAT_TF_EXAMPLE
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Message_xf (InputLayer)     [(None, 1)]               0
#
#  tf.reshape_1 (TFOpLambda)   (None,)                   0
#
#  text_vectorization (TextVec  (None, 100)              0
#  torization)
#
#  embedding (Embedding)       (None, 100, 32)           256000
#
#  bidirectional_1 (Bidirectio  (None, 192)              99072
#  nal)
#
#  dense_3 (Dense)             (None, 48)                9264
#
#  dense_4 (Dense)             (None, 48)                2352
#
#  dropout_1 (Dropout)         (None, 48)                0
#
#  dense_5 (Dense)             (None, 1)                 49
#
# =================================================================
# Total params: 366,737
# Trainable params: 366,737
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/2
#     128/Unknown - 95s 685ms/step - loss: 0.2508 - binary_accuracy: 0.9155
# Epoch 1: val_binary_accuracy improved from -inf to 0.97166, saving model to dhadhan-pipeline\Trainer\model\10\Format-Serving
# WARNING:absl:Function `_wrapped_model` contains input name(s) Message_xf with unsupported characters which will be renamed to message_xf in the SavedModel.
# WARNING:absl:Found untraced functions such as lstm_cell_4_layer_call_fn, lstm_cell_4_layer_call_and_return_conditional_losses, lstm_cell_5_layer_call_fn, lstm_cell_5_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: dhadhan-pipeline\Trainer\model\10\Format-Serving\assets
# INFO:tensorflow:Assets written to: dhadhan-pipeline\Trainer\model\10\Format-Serving\assets
# 128/128 [==============================] - 147s 1s/step - loss: 0.2508 - binary_accuracy: 0.9155 - val_loss: 0.0900 - val_binary_accuracy: 0.9717
# Epoch 2/2
# 128/128 [==============================] - ETA: 0s - loss: 0.0703 - binary_accuracy: 0.9808
# Epoch 2: val_binary_accuracy did not improve from 0.97166
# 128/128 [==============================] - 77s 603ms/step - loss: 0.0703 - binary_accuracy: 0.9808 - val_loss: 0.0896 - val_binary_accuracy: 0.9669
# INFO:tensorflow:struct2tensor is not available.
# INFO:tensorflow:struct2tensor is not available.
# INFO:tensorflow:tensorflow_decision_forests is not available.
# INFO:tensorflow:tensorflow_decision_forests is not available.
# INFO:tensorflow:tensorflow_text is not available.
# INFO:tensorflow:tensorflow_text is not available.
# WARNING:absl:Found untraced functions such as lstm_cell_4_layer_call_fn, lstm_cell_4_layer_call_and_return_conditional_losses, lstm_cell_5_layer_call_fn, lstm_cell_5_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: dhadhan-pipeline\Trainer\model\10\Format-Serving\assets
# INFO:tensorflow:Assets written to: dhadhan-pipeline\Trainer\model\10\Format-Serving\assets
# ExecutionResult(
#     component_id: Trainer
#     execution_id: 10
#     outputs:
#         model: OutputChannel(artifact_type=Model, producer_component_id=Trainer, output_key=model, additional_properties={}, additional_custom_properties={})
#         model_run: OutputChannel(artifact_type=ModelRun, producer_component_id=Trainer, output_key=model_run, additional_properties={}, additional_custom_properties={}))

# %% [markdown]
# ## Resolver

# %%
model_resolver = Resolver(
    strategy_class = LatestBlessedModelStrategy,
    model          = Channel(type=Model),
    model_blessing = Channel(type=ModelBlessing)
).with_id('Latest_blessed_model_resolver')

context.run(model_resolver)
# Out:
# ExecutionResult(
#     component_id: Latest_blessed_model_resolver
#     execution_id: 11
#     outputs:
#         model: OutputChannel(artifact_type=Model, producer_component_id=Latest_blessed_model_resolver, output_key=model, additional_properties={}, additional_custom_properties={})
#         model_blessing: OutputChannel(artifact_type=ModelBlessing, producer_component_id=Latest_blessed_model_resolver, output_key=model_blessing, additional_properties={}, additional_custom_properties={}))

# %% [markdown]
# ## Evaluator

# %%
eval_config = tfma.EvalConfig(
    model_specs   = [tfma.ModelSpec(label_key = 'Category')],
    slicing_specs = [tfma.SlicingSpec()],
    metrics_specs = [
        tfma.MetricsSpec(metrics=[
            tfma.MetricConfig(class_name = 'ExampleCount'),
            tfma.MetricConfig(class_name = 'AUC'),
            tfma.MetricConfig(class_name = 'FalsePositives'),
            tfma.MetricConfig(class_name = 'TruePositives'),
            tfma.MetricConfig(class_name = 'FalseNegatives'),
            tfma.MetricConfig(class_name = 'TrueNegatives'),
            tfma.MetricConfig(class_name = 'BinaryAccuracy',
                threshold=tfma.MetricThreshold(
                    value_threshold = tfma.GenericValueThreshold(
                        lower_bound = {'value': 0.5}
                    ),
                    change_threshold = tfma.GenericChangeThreshold(
                        direction = tfma.MetricDirection.HIGHER_IS_BETTER,
                        absolute  = {'value': 0.0001}
                    )
                )
            )
        ])
    ]
)

# %%
evaluator = Evaluator(
    examples       = example_gen.outputs['examples'],
    model          = trainer.outputs['model'],
    baseline_model = model_resolver.outputs['model'],
    eval_config    = eval_config
)

context.run(evaluator)
# Out:
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x0000023B26114670> and <keras.engine.input_layer.InputLayer object at 0x0000023B31DB96A0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x0000023B26114670> and <keras.engine.input_layer.InputLayer object at 0x0000023B31DB96A0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x0000023B280415B0> and <keras.engine.input_layer.InputLayer object at 0x0000023B2405F910>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x0000023B280415B0> and <keras.engine.input_layer.InputLayer object at 0x0000023B2405F910>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x0000023B39796370> and <keras.engine.input_layer.InputLayer object at 0x0000023B39768250>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x0000023B39796370> and <keras.engine.input_layer.InputLayer object at 0x0000023B39768250>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x0000023B23EF43D0> and <keras.engine.input_layer.InputLayer object at 0x0000023B2818C130>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x0000023B23EF43D0> and <keras.engine.input_layer.InputLayer object at 0x0000023B2818C130>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x0000023B5061FBE0> and <keras.engine.input_layer.InputLayer object at 0x0000023B50451A30>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x0000023B5061FBE0> and <keras.engine.input_layer.InputLayer object at 0x0000023B50451A30>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x0000023B6D2D8B50> and <keras.engine.input_layer.InputLayer object at 0x0000023B6D2AED60>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x0000023B6D2D8B50> and <keras.engine.input_layer.InputLayer object at 0x0000023B6D2AED60>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x0000023B8672D160> and <keras.engine.input_layer.InputLayer object at 0x0000023B866FDE20>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x0000023B8672D160> and <keras.engine.input_layer.InputLayer object at 0x0000023B866FDE20>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x0000023B984146A0> and <keras.engine.input_layer.InputLayer object at 0x0000023B866FDBB0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x0000023B984146A0> and <keras.engine.input_layer.InputLayer object at 0x0000023B866FDBB0>).
# WARNING:tensorflow:From d:\#kuliah\Dicoding\tfx_python3.9\.venv\lib\site-packages\tensorflow_model_analysis\writers\metrics_plots_and_validations_writer.py:110: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`
# WARNING:tensorflow:From d:\#kuliah\Dicoding\tfx_python3.9\.venv\lib\site-packages\tensorflow_model_analysis\writers\metrics_plots_and_validations_writer.py:110: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`
# ExecutionResult(
#     component_id: Evaluator
#     execution_id: 12
#     outputs:
#         evaluation: OutputChannel(artifact_type=ModelEvaluation, producer_component_id=Evaluator, output_key=evaluation, additional_properties={}, additional_custom_properties={})
#         blessing: OutputChannel(artifact_type=ModelBlessing, producer_component_id=Evaluator, output_key=blessing, additional_properties={}, additional_custom_properties={}))

# %% [markdown]
# ### Visualisasi Evaluator

# %%
eval_result = evaluator.outputs['evaluation'].get()[0].uri
tfma_result = tfma.load_eval_result(eval_result)
tfma.view.render_slicing_metrics(tfma_result)
tfma.addons.fairness.view.widget_view.render_fairness_indicator(
    tfma_result
)
# Out:
# FairnessIndicatorViewer(slicingMetrics=[{'sliceValue': 'Overall', 'slice': 'Overall', 'metrics': {'binary_accu…

# %% [markdown]
# ## Pusher
# deploy ke tf serving

# %%
pusher = Pusher(
model=trainer.outputs['model'],
model_blessing=evaluator.outputs['blessing'],
push_destination=pusher_pb2.PushDestination(
    filesystem=pusher_pb2.PushDestination.Filesystem(
        base_directory='serving_model_dir/spam-email-model'))
 
)
 
context.run(pusher)
# Out:
# ExecutionResult(
#     component_id: Pusher
#     execution_id: 13
#     outputs:
#         pushed_model: OutputChannel(artifact_type=PushedModel, producer_component_id=Pusher, output_key=pushed_model, additional_properties={}, additional_custom_properties={}))

# %%
# !pip freeze > requirements.txt
